# %% [markdown]
# # Goal
# The goal of this notebook is to compare the performance of multi-objective probability of improvement backed by a multi-
# objective homogeneous random forest to random search.
#
# # Methodology
# We only need to allow each strategy to execute for some fixed number of iterations. We can subsequently process the resulting observations to estimate the size of the pareto frontier over time.
#
# Specifically, let's first run both strategies on a 2D hypersphere, 10 times each and compare their average performance.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from mlos.OptimizerEvaluationTools.ObjectiveFunctionConfigStore import objective_function_config_store
from mlos.OptimizerEvaluationTools.ObjectiveFunctionFactory import ObjectiveFunctionFactory
from mlos.OptimizerEvaluationTools.SyntheticFunctions.Hypersphere import Hypersphere

from mlos.Optimizers.BayesianOptimizerFactory import BayesianOptimizerFactory, bayesian_optimizer_config_store
from mlos.Optimizers.OptimizationProblem import OptimizationProblem, Objective
from mlos.Optimizers.ParetoFrontier import ParetoFrontier

from mlos.Spaces import Point


objective_function_config = Point(
    implementation=Hypersphere.__name__,
    hypersphere_config=Point(
        num_objectives=2,
        minimize="none",
        radius=10
    )
)
objective_function_config = objective_function_config_store.get_config_by_name("multi_objective_2_mutually_exclusive_polynomials")
objective_function = ObjectiveFunctionFactory.create_objective_function(objective_function_config)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-d50fd7b5463e> in <module>
#      18     )
#      19 )
# ---> 20 objective_function_config = objective_function_config_store.get_config_by_name("multi_objective_2_mutually_exclusive_polynomials")
#      21 objective_function = ObjectiveFunctionFactory.create_objective_function(objective_function_config)
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Spaces\Configs\ComponentConfigStore.py in get_config_by_name(self, name)
#      58         # Throws a Key error if config not found, which is exactly what we want to throw.
#      59         #
# ---> 60         return self._named_configs[name].copy()
#
# KeyError: 'multi_objective_2_mutually_exclusive_polynomials'

# %%
optimization_problem = objective_function.default_optimization_problem

optimizer_config = bayesian_optimizer_config_store.get_config_by_name("default_multi_objective_optimizer_config")

# %%
objectives_dfs_by_run = []
optimizers_by_run = []
num_iterations_per_run = 1000
num_runs = 10

for run_id in range(num_runs):

    optimizer = BayesianOptimizerFactory().create_local_optimizer(
        optimization_problem=optimization_problem,
        optimizer_config=optimizer_config
    )
    
    optimizers_by_run.append(optimizer)

    for i in range(num_iterations_per_run):
        print(f"[{run_id}/{num_runs}][{i+1}/{num_iterations_per_run}]")
        suggestion = optimizer.suggest()
        values = objective_function.evaluate_point(suggestion)
        optimizer.register(suggestion.to_dataframe(), values.to_dataframe())
    
    _, objectives_df, _ = optimizer.get_all_observations()
    objectives_dfs_by_run.append(objectives_df)
# Out:
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 106 -        _create_estimators() ] Creating 10 estimators. Tree config: {
#   "criterion": "mse",
#   "splitter": "best",
#   "max_depth": 0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 3,
#   "min_weight_fraction_leaf": 0,
#   "max_features": "auto",
#   "max_leaf_nodes": 0,
#   "min_impurity_decrease": 0,
#   "ccp_alpha": 0,
#   "min_samples_to_fit": 10,
#   "n_new_samples_before_refit": 10
# }. Request id: 0.6955904544965066
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 106 -        _create_estimators() ] Creating 10 estimators. Tree config: {
#   "criterion": "mse",
#   "splitter": "best",
#   "max_depth": 0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 3,
#   "min_weight_fraction_leaf": 0,
#   "max_features": "auto",
#   "max_leaf_nodes": 0,
#   "min_impurity_decrease": 0,
#   "ccp_alpha": 0,
#   "min_samples_to_fit": 10,
#   "n_new_samples_before_refit": 10
# }. Request id: 0.6955904544965066
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 106 -        _create_estimators() ] Creating 10 estimators. Tree config: {
#   "criterion": "mse",
#   "splitter": "best",
#   "max_depth": 0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 3,
#   "min_weight_fraction_leaf": 0,
#   "max_features": "auto",
#   "max_leaf_nodes": 0,
#   "min_impurity_decrease": 0,
#   "ccp_alpha": 0,
#   "min_samples_to_fit": 10,
#   "n_new_samples_before_refit": 10
# }. Request id: 0.6955904544965066
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 106 -        _create_estimators() ] Creating 10 estimators. Tree config: {
#   "criterion": "mse",
#   "splitter": "best",
#   "max_depth": 0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 3,
#   "min_weight_fraction_leaf": 0,
#   "max_features": "auto",
#   "max_leaf_nodes": 0,
#   "min_impurity_decrease": 0,
#   "ccp_alpha": 0,
#   "min_samples_to_fit": 10,
#   "n_new_samples_before_refit": 10
# }. Request id: 0.6955904544965066
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 106 -        _create_estimators() ] Creating 10 estimators. Tree config: {
#   "criterion": "mse",
#   "splitter": "best",
#   "max_depth": 0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 3,
#   "min_weight_fraction_leaf": 0,
#   "max_features": "auto",
#   "max_leaf_nodes": 0,
#   "min_impurity_decrease": 0,
#   "ccp_alpha": 0,
#   "min_samples_to_fit": 10,
#   "n_new_samples_before_refit": 10
# }. Request id: 0.6955904544965066
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_0_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_0_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_0_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_0_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_0_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_1_input_space
#   Dimensions:
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_1_input_space
#   Dimensions:
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_1_input_space
#   Dimensions:
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_1_input_space
#   Dimensions:
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_1_input_space
#   Dimensions:
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_2_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_2_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_2_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_2_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_2_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_3_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_3_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_3_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_3_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_3_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_4_input_space
#   Dimensions:
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_4_input_space
#   Dimensions:
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_4_input_space
#   Dimensions:
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_4_input_space
#   Dimensions:
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_4_input_space
#   Dimensions:
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_5_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_5_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_5_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_5_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_5_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_6_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_6_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_6_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_6_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_6_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_7_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_7_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_7_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_7_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_7_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_8_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_8_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_8_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_8_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_8_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_9_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_9_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_9_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_9_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_9_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 106 -        _create_estimators() ] Creating 10 estimators. Tree config: {
#   "criterion": "mse",
#   "splitter": "best",
#   "max_depth": 0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 3,
#   "min_weight_fraction_leaf": 0,
#   "max_features": "auto",
#   "max_leaf_nodes": 0,
#   "min_impurity_decrease": 0,
#   "ccp_alpha": 0,
#   "min_samples_to_fit": 10,
#   "n_new_samples_before_refit": 10
# }. Request id: 0.8587861704077935
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 106 -        _create_estimators() ] Creating 10 estimators. Tree config: {
#   "criterion": "mse",
#   "splitter": "best",
#   "max_depth": 0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 3,
#   "min_weight_fraction_leaf": 0,
#   "max_features": "auto",
#   "max_leaf_nodes": 0,
#   "min_impurity_decrease": 0,
#   "ccp_alpha": 0,
#   "min_samples_to_fit": 10,
#   "n_new_samples_before_refit": 10
# }. Request id: 0.8587861704077935
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 106 -        _create_estimators() ] Creating 10 estimators. Tree config: {
#   "criterion": "mse",
#   "splitter": "best",
#   "max_depth": 0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 3,
#   "min_weight_fraction_leaf": 0,
#   "max_features": "auto",
#   "max_leaf_nodes": 0,
#   "min_impurity_decrease": 0,
#   "ccp_alpha": 0,
#   "min_samples_to_fit": 10,
#   "n_new_samples_before_refit": 10
# }. Request id: 0.8587861704077935
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 106 -        _create_estimators() ] Creating 10 estimators. Tree config: {
#   "criterion": "mse",
#   "splitter": "best",
#   "max_depth": 0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 3,
#   "min_weight_fraction_leaf": 0,
#   "max_features": "auto",
#   "max_leaf_nodes": 0,
#   "min_impurity_decrease": 0,
#   "ccp_alpha": 0,
#   "min_samples_to_fit": 10,
#   "n_new_samples_before_refit": 10
# }. Request id: 0.8587861704077935
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 106 -        _create_estimators() ] Creating 10 estimators. Tree config: {
#   "criterion": "mse",
#   "splitter": "best",
#   "max_depth": 0,
#   "min_samples_split": 2,
#   "min_samples_leaf": 3,
#   "min_weight_fraction_leaf": 0,
#   "max_features": "auto",
#   "max_leaf_nodes": 0,
#   "min_impurity_decrease": 0,
#   "ccp_alpha": 0,
#   "min_samples_to_fit": 10,
#   "n_new_samples_before_refit": 10
# }. Request id: 0.8587861704077935
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_0_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_0_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_0_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_0_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_0_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_1_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_1_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_1_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_1_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_1_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___radius: [0.00, 10.00]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_2_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_2_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_2_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_2_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_2_input_space
#   Dimensions:
#     spherical_coordinates___radius: [0.00, 10.00]
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_3_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_3_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_3_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_3_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_3_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_4_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_4_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_4_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_4_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_4_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_5_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_5_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_5_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_5_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_5_input_space
#   Dimensions:
#     spherical_coordinates___theta1: [0.00, 1.57]
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___radius: [0.00, 10.00]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_6_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_6_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_6_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_6_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator_6_input_space
#   Dimensions:
#     contains_context: {False}
#     spherical_coordinates___theta0: [0.00, 1.57]
#     spherical_coordinates___theta1: [0.00, 1.57]
# 01/23/2021 03:45:03 -   BayesianOptimizerFactory -    INFO - [HomogeneousRandomForestRegressionModel.py: 120 -        _create_estimators() ] Creating DecissionTreeRegressionModel with the input_space:   Name: estimator

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-cfe55cec1d5e> in <module>
#      15     for i in range(num_iterations_per_run):
#      16         print(f"[{run_id}/{num_runs}][{i+1}/{num_iterations_per_run}]")
# ---> 17         suggestion = optimizer.suggest()
#      18         values = objective_function.evaluate_point(suggestion)
#      19         optimizer.register(suggestion.to_dataframe(), values.to_dataframe())
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Tracer.py in wrapper(*args, **kwargs)
#      57
#      58             else:
# ---> 59                 result = wrapped_function(*args, **kwargs)
#      60
#      61             return result
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Optimizers\BayesianOptimizer.py in suggest(self, random, context)
#     140         context_values = context.to_dataframe() if context is not None else None
#     141         pareto_frontier = ParetoFrontier(self.optimization_problem, self._target_values_df)
# --> 142         suggested_config = self.experiment_designer.suggest(random=random, context_values_dataframe=context_values)
#     143         assert suggested_config in self.optimization_problem.parameter_space
#     144         return suggested_config
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Optimizers\ExperimentDesigner\ExperimentDesigner.py in suggest(self, context_values_dataframe, random)
#     156         if random:
#     157             return self.optimization_problem.parameter_space.random()
# --> 158         return self.numeric_optimizer.suggest(context_values_dataframe)
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Tracer.py in wrapper(*args, **kwargs)
#      57
#      58             else:
# ---> 59                 result = wrapped_function(*args, **kwargs)
#      60
#      61             return result
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Optimizers\ExperimentDesigner\UtilityFunctionOptimizers\RandomSearchOptimizer.py in suggest(self, context_values_dataframe)
#      59             product=True
#      60         )
# ---> 61         utility_function_values = self.utility_function(feature_values_pandas_frame=feature_values_dataframe.copy(deep=False))
#      62         num_utility_function_values = len(utility_function_values.index)
#      63         index_of_max_value = utility_function_values[['utility']].idxmax()['utility'] if num_utility_function_values > 0 else 0
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Tracer.py in wrapper(*args, **kwargs)
#      57
#      58             else:
# ---> 59                 result = wrapped_function(*args, **kwargs)
#      60
#      61             return result
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Optimizers\ExperimentDesigner\UtilityFunctions\MultiObjectiveProbabilityOfImprovementUtilityFunction.py in __call__(self, feature_values_pandas_frame)
#     109             std_dev_column_name = objective_prediction.add_standard_deviation_column()
#     110
# --> 111         batched_poi_df = self._batched_poi(
#     112             multi_objective_predictions=multi_objective_predictions,
#     113             valid_predictions_index=valid_predictions_index,
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Tracer.py in wrapper(*args, **kwargs)
#      57
#      58             else:
# ---> 59                 result = wrapped_function(*args, **kwargs)
#      60
#      61             return result
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Optimizers\ExperimentDesigner\UtilityFunctions\MultiObjectiveProbabilityOfImprovementUtilityFunction.py in _batched_poi(self, multi_objective_predictions, valid_predictions_index, std_dev_column_name)
#     142
#     143         for config_idx in valid_predictions_index:
# --> 144             monte_carlo_samples_df = self.create_monte_carlo_samples_df(
#     145                 multi_objective_predictions=multi_objective_predictions,
#     146                 config_idx=config_idx,
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Tracer.py in wrapper(*args, **kwargs)
#      57
#      58             else:
# ---> 59                 result = wrapped_function(*args, **kwargs)
#      60
#      61             return result
#
# c:\users\adam_\source\mlos\source\mlos.python\mlos\Optimizers\ExperimentDesigner\UtilityFunctions\MultiObjectiveProbabilityOfImprovementUtilityFunction.py in create_monte_carlo_samples_df(self, multi_objective_predictions, config_idx, std_dev_column_name)
#     211             prediction_df = prediction.get_dataframe()
#     212             config_prediction = prediction_df.loc[config_idx]
# --> 213             monte_carlo_samples_df[objective_name] = np.random.standard_t(config_prediction[dof_col], self.config.num_monte_carlo_samples) \
#     214                                                      * config_prediction[std_dev_column_name] \
#     215                                                      + config_prediction[predicted_value_col]
#
# KeyboardInterrupt:

# %%
pareto_volumes_over_time_per_run = [[] for i in range(10, 1001, 10)]
for run_id, objectives_df in enumerate(objectives_dfs_by_run):
    for i, j in enumerate(range(10, 1001, 10)):
        pareto_frontier = ParetoFrontier(optimization_problem=optimization_problem, objectives_df=objectives_df[:j])
        pareto_volume_estimator = pareto_frontier.approximate_pareto_volume(num_samples=1000000)
        lower_bound, upper_bound = pareto_volume_estimator.get_two_sided_confidence_interval_on_pareto_volume(alpha=0.05)
        pareto_volume = (lower_bound + upper_bound) / 2
        pareto_volumes_over_time_per_run[i].append(pareto_volume)

# %%
average_pareto_volume_by_iteration = [sum(pareto_volumes) / len(pareto_volumes) for pareto_volumes in pareto_volumes_over_time_per_run]

# %%
average_pareto_volume_by_iteration
# Out:
# [38.871809851218934,
#  45.71594768769588,
#  46.819235360124416,
#  52.30936098473916,
#  54.43703609770653,
#  56.69644911580693,
#  57.15738507791809,
#  58.15193904935585,
#  59.64668063473996,
#  59.94915013056329,
#  60.909858313697434,
#  61.55313084039012,
#  61.640661012685314,
#  61.62559135885258,
#  61.95918781161348,
#  62.94344270625303,
#  63.22763226888728,
#  63.2849306210062,
#  64.15028511768122,
#  64.61302576093311,
#  64.69656981855742,
#  65.19226882892669,
#  65.28707597940434,
#  65.42653118322457,
#  65.44922289491659,
#  65.8092004460206,
#  66.38826207023327,
#  66.97334249795938,
#  66.98127222470303,
#  67.0839681869209,
#  67.29394552371475,
#  67.30147160569915,
#  67.53590941686643,
#  67.66919169460384,
#  67.79434688060334,
#  67.83580055779105,
#  68.0320643753335,
#  68.0592417880511,
#  68.16811211862817,
#  68.20988051641999,
#  68.87404477774506,
#  68.85969848254321,
#  68.88665736289926,
#  68.88450893505033,
#  69.09416101635325,
#  69.19418457819246,
#  69.18516196656925,
#  69.33633199065407,
#  69.45162278176282,
#  69.63077421152583,
#  69.84891578737218,
#  70.04900343717756,
#  70.09127647848582,
#  70.30861764345514,
#  70.38382312643475,
#  70.34524181553842,
#  70.47020034608126,
#  70.50042913774443,
#  70.49015446377241,
#  70.71123803072992,
#  70.8676696309936,
#  70.88593437337637,
#  70.92346688703607,
#  70.97095807314372,
#  71.06074202722962,
#  71.27250498582698,
#  71.28437921780461,
#  71.27977716806443,
#  71.35011633947526,
#  71.33168805739352,
#  71.41216561472797,
#  71.41087900043483,
#  71.44574717221387,
#  71.45210967236312,
#  71.47209297482767,
#  71.48924507483656,
#  71.47286299139103,
#  71.56548102163386,
#  71.6229598415485,
#  71.62523148592702,
#  71.63349477723449,
#  71.73417364266349,
#  71.76559412860713,
#  71.81725329590803,
#  71.84333937153421,
#  71.8785072581612,
#  71.99853987962302,
#  72.05869565975168,
#  72.06051523659973,
#  72.0771123358511,
#  72.0880856916135,
#  72.11844927702562,
#  72.13227092298074,
#  72.1474628131196,
#  72.28235149131304,
#  72.29017379733266,
#  72.35303741361479,
#  72.37865164443944,
#  72.42510301617422,
#  72.44754748964414]

# %%
# Now let's do the random ones :)
#
num_runs = 6
objectives_dfs_by_random_run = []

for run_id in range(num_runs):
    suggestions_df = objective_function.parameter_space.random_dataframe(num_iterations_per_run)
    objectives_df = objective_function.evaluate_dataframe(suggestions_df)
    objectives_dfs_by_random_run.append(objectives_df)
    
pareto_volumes_over_time_per_random_run = [[] for i in range(10, 1001, 10)]
for run_id, objectives_df in enumerate(objectives_dfs_by_random_run):
    for i, j in enumerate(range(10, 1001, 10)):
        pareto_frontier = ParetoFrontier(optimization_problem=optimization_problem, objectives_df=objectives_df[:j])
        pareto_volume_estimator = pareto_frontier.approximate_pareto_volume(num_samples=1000000)
        lower_bound, upper_bound = pareto_volume_estimator.get_two_sided_confidence_interval_on_pareto_volume(alpha=0.05)
        pareto_volume = (lower_bound + upper_bound) / 2
        pareto_volumes_over_time_per_random_run[i].append(pareto_volume)

average_random_pareto_volume_by_iteration = [sum(pareto_volumes) / len(pareto_volumes) for pareto_volumes in pareto_volumes_over_time_per_random_run]

# %%
average_random_pareto_volume_by_iteration
# Out:
# [43.34838527959629,
#  46.13215461731599,
#  50.68639245315601,
#  53.2303834923118,
#  55.390656475251326,
#  59.06495678103476,
#  60.190309081620576,
#  61.852302777630335,
#  63.06227489122472,
#  64.44895933493261,
#  65.67202521847699,
#  66.26305409300288,
#  66.77572672958189,
#  66.85195769636165,
#  67.18296828088188,
#  67.36172743452204,
#  67.77867215658269,
#  67.89538885744238,
#  68.07693795043656,
#  68.35441774407462,
#  68.44475642988095,
#  69.08450632920538,
#  69.48334939451678,
#  69.70038460445373,
#  69.97113469148853,
#  70.12773267431338,
#  70.22939437290073,
#  70.27608767926615,
#  70.4041188891408,
#  70.42105736125627,
#  70.59502125406519,
#  70.81273616728176,
#  70.89221712531652,
#  70.96758407924845,
#  70.99941686078033,
#  71.13853471172199,
#  71.11653438433912,
#  71.29343931899125,
#  71.29746615612679,
#  71.41470945241802,
#  71.41734195485357,
#  71.53696622234332,
#  71.89482186991006,
#  71.98331946823002,
#  71.9987147854428,
#  72.01984270350572,
#  72.12138721430894,
#  72.14735158626107,
#  72.22669256582832,
#  72.25887248833504,
#  72.29750614950875,
#  72.3012678254964,
#  72.30902999259574,
#  72.40262463146554,
#  72.41181912895246,
#  72.41238054785347,
#  72.44721589262777,
#  72.46475623161047,
#  72.68578826934743,
#  72.67009839397831,
#  72.678976678401,
#  72.73294988599912,
#  72.80546998476454,
#  72.82580331115612,
#  72.83783182814348,
#  72.88455708445359,
#  72.83550488178612,
#  72.96147175558644,
#  73.0044606110571,
#  73.01765090077731,
#  73.0097183349475,
#  73.06308740643368,
#  73.05815219242048,
#  73.05985181369458,
#  73.04722241430831,
#  73.190216908264,
#  73.1720724438516,
#  73.28281819180616,
#  73.2462593535979,
#  73.34433839690153,
#  73.42985382566373,
#  73.3637519299627,
#  73.41878244355671,
#  73.40241739674967,
#  73.38152046868795,
#  73.4551261405778,
#  73.47857503109924,
#  73.48215292601826,
#  73.5211056952387,
#  73.60643775452847,
#  73.56416349171185,
#  73.58531708732289,
#  73.61454132103808,
#  73.62941111537758,
#  73.58798454217013,
#  73.65581249576863,
#  73.60452403709071,
#  73.6016150643436,
#  73.73650773872474,
#  73.74098777311436]

# %%
import plotly.graph_objs as go
fig = go.Figure()
fig.add_trace(go.Scatter(
    x